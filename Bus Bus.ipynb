# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('internet percentage source.csv')
df = df.set_index('Country')
del df['S/N']
df
# Out:
#                                2019   2018       2017       2016       2015  \
# Country
# Algeria                       18.09  16.50  15.228027  14.000000  12.500000
# Angola                        21.26  19.10  16.937210  14.776000  10.000000
# Benin                          5.30   4.90   4.500000   4.148323   3.130000
# Botswana                      18.50  15.00  11.500000   8.000000   6.000000
# Burkina Faso                   9.40   9.10   3.725035   3.000000   2.400000
# Burundi                        1.38   1.30   1.220000   1.110000   1.000000
# Cameroon                      11.00   6.40   5.698987   5.000000   4.300000
# Cape Verde                    40.26  37.50  34.740000  32.000000  30.000000
# Central African Republic       4.03   3.50   3.000000   2.200000   2.000000
# Chad                           2.50   2.30   2.100000   1.900000   1.700000
# Comoros                        6.98   6.50   5.975296   5.500000   5.100000
# Congo                          7.11   6.60   6.106695   5.600000   5.000000
# Democratic Republic of Congo   3.00   2.20   1.679961   1.200000   0.720000
# Djibouti                      10.71   9.50   8.267233   7.000000   6.500000
# Egypt                         31.70  29.40  26.400000  25.600000  21.600000
# Equitorial Guinea             18.86  16.40  13.943182  11.500000   6.000000
# Eritrea                        0.99   0.90   0.800000   0.700000   0.610000
# Ethiopia                       2.90   1.90   1.482810   1.100000   0.750000
# Gabon                          9.81   9.20   8.616714   8.000000   7.230000
# Ghana                         18.90  12.30  10.600000   9.000000   7.800000
# Guinea-Bissau                  3.32   3.10   2.893991   2.672000   2.450000
# Ivory Coast                    9.67   9.16   8.720000   8.350000   8.110000
# Kenya                         43.40  39.00  32.100000  28.000000  14.000000
# Lesotho                       11.00   5.00   4.589618   4.224800   3.860000
# Liberia                        5.41   3.20   2.600000   2.500000   2.300000
# Libya                         17.76  16.50  14.000000  14.000000  10.800000
# Madagascar                     3.70   3.00   2.300000   1.900000   1.700000
# Malawi                         5.83   5.05   4.350600   3.330000   2.260000
# Mali                           7.00   3.50   2.800000   2.200000   2.000000
# Mauritania                    10.70   6.20   5.000000   4.500000   4.000000
# Mauritius                     41.44  39.00  35.420000  34.950000  28.330000
# Morocco                       56.80  56.00  55.416053  46.107483  52.000000
# Mozambique                     5.94   5.40   4.849100   4.300000   4.170000
# Namibia                       14.84  13.90  12.941400  12.000000  11.600000
# Niger                          1.95   1.70   1.407700   1.300000   0.830000
# Nigeria                       42.68  38.00  32.800000  28.430000  24.000000
# Rwanda                        10.60   9.00   8.023854   7.000000   8.000000
# Sao Tome and Principe         24.41  23.00  21.572400  20.161200  18.750000
# Senegal                       17.70  13.10  10.800000   9.800000   8.000000
# Seychelles                    54.26  50.40  47.076000  43.164004  41.000000
# Sierra Leone                   2.10   1.70   1.300000   0.900000   0.580000
# Somalia                        1.63   1.50   1.376700   1.250000   1.160611
# South Africa                  49.00  46.50  41.000000  33.970000  24.000000
# South Sudan                   15.90  14.10   7.000000   6.210000   6.002000
# Somalia                        1.142687   1.122236   1.100216   1.077328
# South Africa                  10.000000   8.430000   8.065375   7.607140
# South Sudan                    5.879000   5.621000   5.580000   5.360000
# Sudan                          8.660000   1.292041   1.150000   1.020000
# Swaziland                      8.940000   6.850000   4.100000   3.696539
# Tanzania                       2.400000   1.900000   1.600000   1.300000
# Togo                           2.600000   2.400000   2.200000   2.000000
# Tunisia                       34.070000  27.530000  17.100000  12.986409
# Uganda                         9.780000   7.900000   3.671965   2.529363
# Zambia                         6.310000   5.550000   4.870000   4.159913
# Zimbabwe                      11.360000  11.400000  10.850000   9.791842
#
#                                    2010
# Country
# Algeria                        5.843942
# Angola                         1.143367
# Benin                          1.271031
# Botswana                       3.262554
# Burkina Faso                   0.469914
# Burundi                        0.542143
# Cameroon                       1.402654
# Cape Verde                     6.074087
# Central African Republic       0.268196
# Chad                           0.399258
# Comoros                        2.000000
# Congo                          1.463420
# Democratic Republic of Congo   0.238038
# Djibouti                       0.953611
# Egypt                         12.750000
# Equitorial Guinea              1.149790
# Eritrea                        0.358000
# Ethiopia                       0.219660
# Gabon                          4.893265
# Ghana                          1.831197
# Guinea-Bissau                  1.901365
# Ivory Coast                    7.010000
# Kenya                          3.101898
# Lesotho                        2.580245
# Liberia                        0.490000
# Libya                          3.720000
# Madagascar                     0.567722
# Malawi                         0.384489
# Mali                           0.507063
# Mauritania                     0.669966
# Mauritius                     15.172229
# Morocco                       15.084445
# Mozambique                     0.854357
# Namibia                        4.010047
# Niger                          0.221341
# Nigeria                        3.549156
# Rwanda                         0.000000
# Sao Tome and Principe          0.489000
# Senegal                        4.786684
# Seychelles                    23.780000
# Sierra Leone                   0.215392
# Somalia                        1.030060
# South Africa                   7.488543
# South Sudan                    4.980000
# Sudan                          0.978000
# Swaziland                      3.696961
# Tanzania                       1.100000
# Togo                           1.800000
# Tunisia                        9.655087
# Uganda                         1.742206
# Zambia                         2.851752
# Zimbabwe                       8.015978

# %%
for year in range(2010,2020):
    fig,ax = plt.subplots(1)
    df[str(year)].plot.barh(ax=ax, figsize=(10,10), title=f"Percentage of People using the Internet on Year {year}")
    ax.set_xlabel('Internet Percentage (%)')

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].mean())
    
plt.plot(range(2010,2020), vals)
plt.title('Mean')
plt.xlabel('Year')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].median())
    

plt.title('Median')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].std())
    

plt.title('Stdev')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
vals = []
for year in range(2010,2020):
    vals.append(df[str(year)].var())
    

plt.title('Var')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def iqr(sample):
    return sample.quantile(0.75) - sample.quantile(0.25)

vals = []
for year in range(2010,2020):
    vals.append(iqr(df[str(year)]))
    

plt.title('IQR')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def siqr(sample):
    return (sample.quantile(0.75) - sample.quantile(0.25))/2

vals = []
for year in range(2010,2020):
    vals.append(siqr(df[str(year)]))
    

plt.title('SIQR')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)

# %%
def _range(sample):
    return sample.max() - sample.min()

vals = []
for year in range(2010,2020):
    vals.append(_range(df[str(year)]))
    

plt.title('Range')
plt.xlabel('Year')
plt.ylabel('Percentage')    
plt.plot(range(2010,2020), vals)
